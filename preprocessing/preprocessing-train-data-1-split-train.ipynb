# %%
import csv
import cv2
import itertools
import numpy as np
import pandas as pd
import os
import sys
import tempfile
import tqdm
from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection

import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Downloading model from TF Hub and checking out the inference code from GitHub
# !wget -q -O movenet_thunder.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/float16/4?lite-format=tflite
# !git clone https://github.com/tensorflow/examples.git
pose_sample_rpi_path = os.path.join(os.getcwd(), 'examples/lite/examples/pose_estimation/raspberry_pi')
sys.path.append(pose_sample_rpi_path)

# Loading MoveNet Thunder model
import utils
from data import BodyPart
from ml import Movenet
movenet = Movenet('movenet_thunder')

# Defining function to run pose estimation using MoveNet Thunder.
def detect(input_tensor, inference_count=3):
  image_height, image_width, channel = input_tensor.shape

  # Detect pose using the full input image
  movenet.detect(input_tensor.numpy(), reset_crop_region=True)

  # Repeatedly using previous detection result to identify the region of
  # interest and only croping that region to improve detection accuracy
  for _ in range(inference_count - 1):
    person = movenet.detect(input_tensor.numpy(), 
                            reset_crop_region=False)

  return person
# Out:
# fatal: destination path 'examples' already exists and is not an empty directory.

# %%
def draw_prediction_on_image(
    image, person, crop_region=None, close_figure=True,
    keep_input_size=False):
  
  # Draw the detection result on top of the image.
  image_np = utils.visualize(image, [person])
  # Plot the image with detection results.
  height, width, channel = image.shape
  aspect_ratio = float(width) / height
  fig, ax = plt.subplots(figsize=(12 * aspect_ratio, 12))
  im = ax.imshow(image_np)

  if close_figure:
    plt.close(fig)

  if not keep_input_size:
    image_np = utils.keep_aspect_ratio_resizer(image_np, (512, 512))

  return image_np

# %%
class MoveNetPreprocessor(object):
  """Helper class to preprocess pose sample images for classification."""

  def __init__(self,
               images_in_folder,
               images_out_folder,
               csvs_out_path):
    """Creates a preprocessor to detection pose from images and save as CSV.

    Args:
      images_in_folder: Path to the folder with the input images. It should
        follow this structure:
        yoga_poses
        |__ downdog
            |______ 00000128.jpg
            |______ 00000181.bmp
            |______ ...
        |__ goddess
            |______ 00000243.jpg
            |______ 00000306.jpg
            |______ ...
        ...
      images_out_folder: Path to write the images overlay with detected
        landmarks. These images are useful when you need to debug accuracy
        issues.
      csvs_out_path: Path to write the CSV containing the detected landmark
        coordinates and label of each image that can be used to train a pose
        classification model.
    """
    self._images_in_folder = images_in_folder
    self._images_out_folder = images_out_folder
    self._csvs_out_path = csvs_out_path
    self._messages = []

    # Create a temp dir to store the pose CSVs per class
    self._csvs_out_folder_per_class = tempfile.mkdtemp()

    # Get list of pose classes and print image statistics
    self._pose_class_names = sorted(
        [n for n in os.listdir(self._images_in_folder) if not n.startswith('.')]
        )

  def process(self, per_pose_class_limit=None, detection_threshold=0.1):
    """Preprocesses images in the given folder.
    Args:
      per_pose_class_limit: Number of images to load. As preprocessing usually
        takes time, this parameter can be specified to make the reduce of the
        dataset for testing.
      detection_threshold: Only keep images with all landmark confidence score
        above this threshold.
    """
    # Loop through the classes and preprocess its images
    for pose_class_name in self._pose_class_names:
      print('Preprocessing', pose_class_name, file=sys.stderr)

      # Paths for the pose class.
      images_in_folder = os.path.join(self._images_in_folder, pose_class_name)
      images_out_folder = os.path.join(self._images_out_folder, pose_class_name)
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  pose_class_name + '.csv')
      if not os.path.exists(images_out_folder):
        os.makedirs(images_out_folder)

      # Detect landmarks in each image and write it to a CSV file
      with open(csv_out_path, 'w') as csv_out_file:
        csv_out_writer = csv.writer(csv_out_file, 
                                    delimiter=',', 
                                    quoting=csv.QUOTE_MINIMAL)
        # Get list of images
        image_names = sorted(
            [n for n in os.listdir(images_in_folder) if not n.startswith('.')])
        if per_pose_class_limit is not None:
          image_names = image_names[:per_pose_class_limit]

        valid_image_count = 0

        # Detect pose landmarks from each image
        for image_name in tqdm.tqdm(image_names):
          image_path = os.path.join(images_in_folder, image_name)

          try:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
          except Exception as e:
            print(f'Error reading/decoding image: {image_path}')
            print(e)  # Print the exception details
            self._messages.append(f'Skipped {image_path}. Invalid image.')
            continue
          else:
            image_height, image_width, channel = image.shape


          # Skip images that isn't RGB because Movenet requires RGB images
          if channel != 3:
            self._messages.append('Skipped ' + image_path +
                                  '. Image isn\'t in RGB format.')
            continue
          person = detect(image)

          # Save landmarks if all landmarks were detected
          min_landmark_score = min(
              [keypoint.score for keypoint in person.keypoints])
          should_keep_image = min_landmark_score >= detection_threshold
          if not should_keep_image:
            self._messages.append('Skipped ' + image_path +
                                  '. No pose was confidentlly detected.')
            continue

          valid_image_count += 1

          # Draw the prediction result on top of the image for debugging later
          output_overlay = draw_prediction_on_image(
              image.numpy().astype(np.uint8), person, 
              close_figure=True, keep_input_size=True)

          # Write detection result into an image file
          output_frame = cv2.cvtColor(output_overlay, cv2.COLOR_RGB2BGR)
          cv2.imwrite(os.path.join(images_out_folder, image_name), output_frame)

          # Get landmarks and scale it to the same size as the input image
          pose_landmarks = np.array(
              [[keypoint.coordinate.x, keypoint.coordinate.y, keypoint.score]
                for keypoint in person.keypoints],
              dtype=np.float32)

          # Write the landmark coordinates to its per-class CSV file
          coordinates = pose_landmarks.flatten().astype(np.str).tolist()
          csv_out_writer.writerow([image_name] + coordinates)

        if not valid_image_count:
          raise RuntimeError(
              'No valid images found for the "{}" class.'
              .format(pose_class_name))
        
    # Print the error message collected during preprocessing.
    print('\n'.join(self._messages))

    # Combine all per-class CSVs into a single output file
    all_landmarks_df = self._all_landmarks_as_dataframe()
    all_landmarks_df.to_csv(self._csvs_out_path, index=False)

  def class_names(self):
    """List of classes found in the training dataset."""
    return self._pose_class_names

  def _all_landmarks_as_dataframe(self):
    """Merge all per-class CSVs into a single dataframe."""
    total_df = None
    for class_index, class_name in enumerate(self._pose_class_names):
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  class_name + '.csv')
      per_class_df = pd.read_csv(csv_out_path, header=None)

      # Add the labels
      per_class_df['class_no'] = [class_index]*len(per_class_df)
      per_class_df['class_name'] = [class_name]*len(per_class_df)

      # Append the folder name to the filename column (first column)
      per_class_df[per_class_df.columns[0]] = (os.path.join(class_name, '') 
        + per_class_df[per_class_df.columns[0]].astype(str))

      if total_df is None:
        # For the first class, assign its data to the total dataframe
        total_df = per_class_df
      else:
        # Concatenate each class's data into the total dataframe
        total_df = pd.concat([total_df, per_class_df], axis=0)

    list_name = [[bodypart.name + '_x', bodypart.name + '_y', 
                  bodypart.name + '_score'] for bodypart in BodyPart] 
    header_name = []
    for columns_name in list_name:
      header_name += columns_name
      header_name = ['file_name'] + header_name
      header_map = {total_df.columns[i]: header_name[i] 
                      for i in range(len(header_name))}

      total_df.rename(header_map, axis=1, inplace=True)

      return total_df

# %% [markdown]
# # > **Preprocessing the Train Data**

# %%
is_skip_step_1 = False

# %%
use_custom_dataset = True

dataset_is_split = True

# %%
dataset_in = '/kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1'

# You can leave the rest alone:
if not os.path.isdir(dataset_in):
  raise Exception("dataset_in is not a valid directory")
if dataset_is_split:
  IMAGES_ROOT = dataset_in
else:
  dataset_out = 'split_' + dataset_in
  split_into_train_test(dataset_in, dataset_out, test_split=0.2)
  IMAGES_ROOT = dataset_out

# %%
if not is_skip_step_1:
  images_in_train_folder = os.path.join(IMAGES_ROOT)
  images_out_train_folder = 'poses_images_out_train_1'
  csvs_out_train_path = 'train_data.csv'

  preprocessor = MoveNetPreprocessor(
      images_in_folder=images_in_train_folder,
      images_out_folder=images_out_train_folder,
      csvs_out_path=csvs_out_train_path,
  )

  preprocessor.process(per_pose_class_limit=None)
# Out:
# Preprocessing 0_0_18
#   0%|          | 0/149 [00:00<?, ?it/s]/tmp/ipykernel_32/3091940554.py:127: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   coordinates = pose_landmarks.flatten().astype(np.str).tolist()
# 100%|██████████| 149/149 [00:23<00:00,  6.32it/s]
# Preprocessing 0_0_68
# 100%|██████████| 148/148 [00:24<00:00,  5.93it/s]
# Preprocessing 0_0_8
#  64%|██████▎   | 107/168 [00:18<00:10,  5.99it/s]/opt/conda/lib/python3.10/site-packages/numpy/lib/function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /opt/conda/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 168/168 [00:28<00:00,  5.88it/s]
# Preprocessing 0_1_16
# 100%|██████████| 40/40 [00:06<00:00,  6.59it/s]
# Preprocessing 0_1_17
# 100%|██████████| 166/166 [00:28<00:00,  5.76it/s]
# Preprocessing 0_1_36
# 100%|██████████| 95/95 [00:14<00:00,  6.50it/s]
# Preprocessing 0_1_60
# 100%|██████████| 213/213 [00:34<00:00,  6.17it/s]
# Preprocessing 0_1_77
# 100%|██████████| 146/146 [00:21<00:00,  6.86it/s]
# Preprocessing 0_2_21
# 100%|██████████| 288/288 [00:43<00:00,  6.67it/s]
# Preprocessing 0_2_22
# 100%|██████████| 292/292 [00:48<00:00,  6.05it/s]
# Preprocessing 0_2_29
# 100%|██████████| 82/82 [00:12<00:00,  6.72it/s]
# Preprocessing 0_2_31
# 100%|██████████| 136/136 [00:21<00:00,  6.26it/s]
# Preprocessing 0_2_40
# 100%|██████████| 129/129 [00:22<00:00,  5.65it/s]
# Preprocessing 0_2_75
jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_2_75/70202.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_2_75/72369.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_2_75/72638.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/00683.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/02572.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/04261.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/06094.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/06229.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/07897.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/12343.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/13476.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/13873.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/14073.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/16878.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/17453.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/18999.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/23331.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/24681.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/28408.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/28735.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/32607.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/32821.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/33097.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/33970.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/37041.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/39220.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/39957.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/41384.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/41399.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/41907.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/42220.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/42508.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/42658.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/42738.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/46386.jpg. Image isn't in RGB format.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/47070.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/50803.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/51117.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/51525.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/53075.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/54706.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/56430.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/57847.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/58429.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/59683.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/59999.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/65096.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/66248.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/66357.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/67834.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/68650.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/69296.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/69775.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/70864.jpg. Image isn't in RGB format.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/71560.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_39/72784.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_61/01833.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_61/06667.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/0_3_61/07294.jpg. No pose was confidentlly detected.
# ...
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_0/70881.jpg. Image isn't in RGB format.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_0/74480.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_35/04588.jpg. Image isn't in RGB format.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_35/05166.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_35/11341.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_35/26026.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_35/32777.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_35/32829.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_35/36920.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_35/41735.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_35/50427.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_35/69319.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_35/71325.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_35/71890.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/00043.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/04372.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/04868.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/06816.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/09319.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/10322.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/11079.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/12521.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/16172.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/16284.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/18854.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/22800.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/23767.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/24039.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/26923.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/28342.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/28656.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/29931.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/29976.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/31325.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/32006.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/37780.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/40159.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/40844.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/41924.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/46145.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/48760.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/49254.jpg. Image isn't in RGB format.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/49360.jpg. Image isn't in RGB format.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/49812.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/49921.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/52869.jpg. Image isn't in RGB format.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/56169.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/56828.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/60007.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/66694.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/67274.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/67418.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/73591.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/1_8_47/73998.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/03314.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/10319.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/12555.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/19719.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/22894.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/23393.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/39179.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/57453.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/60002.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/62575.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/64784.jpg. Image isn't in RGB format.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/65732.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/68132.jpg. Image isn't in RGB format.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/71828.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/73035.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/73059.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_11/73202.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/13464.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/18872.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/19667.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/19831.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/23162.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/23589.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/23704.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/33790.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/36991.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/37923.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/40802.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/45227.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/46100.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/47366.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/50876.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/63268.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/67074.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/68595.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/71358.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_14/72574.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/00731.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/00852.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/05178.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/18750.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/21579.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/22085.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/22361.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/23673.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/25620.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/27107.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/28355.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/28566.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/28810.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/31540.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/32477.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/33023.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/34046.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/34922.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/36693.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/37875.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/42225.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/42982.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/46479.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/48957.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/51294.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/52614.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/53282.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/55277.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/57870.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/65653.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/67822.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/69172.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/70679.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/73625.jpg. No pose was confidentlly detected.
# Skipped /kaggle/input/split-data-from-train-of-aii2022-human-pose/train_1/2_9_24/74055.jpg. No pose was confidentlly detected.

# %%
import zipfile

# Define the path of the folder you want to download
folder_path = '/kaggle/working/poses_images_out_train_1'

# Define the path of the .zip file you want to create
zip_file_path = '/kaggle/working/output_train_1.zip'

# Create a .zip file containing the contents of the folder
with zipfile.ZipFile(zip_file_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, _, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            arcname = os.path.relpath(file_path, folder_path)
            zipf.write(file_path, arcname)

print(f"Folder '{folder_path}' has been compressed and saved as '{zip_file_path}'.")
# Out:
# Folder '/kaggle/working/poses_images_out_train_1' has been compressed and saved as '/kaggle/working/output_train_1.zip'.

# %%
import IPython
IPython.display.FileLink('output_train_1.zip')
# Out:
# /kaggle/working/output_train_1.zip
